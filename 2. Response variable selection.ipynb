# %% [markdown]
# # Selecting the response variable
# To understand how economic crises affect a bank’s financial stability, it is important to choose a key financial metric as a response variable that is both vital for a bank’s health and significantly impacted during downturns. Several options were considered, including income and loss components, capital ratios, and liquidity measures

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
from sample_panel.filtering import bank_filtering
from sample_panel.response_var import response_variables
from EDA.panel_vis import plot_response_var

# %% [markdown]
# ## Loading Data

# %%
bank_panel_df = pd.read_csv('df_bank_panel.csv')

# %% [markdown]
# ## Preparing Sample

# %%
# Select banks that meet the eligibility criteria
bank_panel_df = bank_filtering(bank_panel_df)

# %%
# Select potential options for the response variable
bank_panel_df = response_variables(bank_panel_df)

# %%
bank_panel_df.tail(5)
# Out:
#       Report Date   IDRSSD        Financial Institution Name  \
# 17005  2023-06-30  3637685             FIRST FOUNDATION BANK
# 17006  2023-06-30  3650808          LIVE OAK BANKING COMPANY
# 17007  2023-06-30  3783313                  CROSS RIVER BANK
# 17008  2023-06-30  3938186  BANKUNITED, NATIONAL ASSOCIATION
# 17009  2023-06-30  5278251         CHARLES SCHWAB TRUST BANK
#
#        Provision for Loan Lease Losses as % of Aver. Assets  \
# 17005                                               0.00
# 17006                                               0.62
# 17007                                               0.51
# 17008                                               0.17
# 17009                                               0.00
#
#        Provision_quarter as % of Assets  \
# 17005                          0.027701
# 17006                          0.486209
# 17007                          1.196816
# 17008                          0.173450
# 17009                          0.000000
#
#        Net Interest Income as % of Aver. Assets  \
# 17005                                      1.71
# 17006                                      3.20
# 17007                                      5.73
# 17008                                      2.50
# 17009                                      1.88
#
#        Noninterest Income as % of Aver. Assets  \
# 17005                                     0.11
# 17006                                     0.67
# 17007                                     0.23
# 17008                                     0.28
# 17009                                     0.80
#
#        Pre Provision Net Revenue as % of Aver. Assets  \
# 17005                                       -2.950536
# 17006                                        1.068347
# 17007                                        1.548875
# 17008                                        1.206769
# 17009                                        1.815265
#
#        Tier One Leverage Capital  \
# 17005                     8.2105
# 17006                     7.2259
# 17007                    14.6899
# 17008                     8.7865
# 17009                     9.7809
#
#        Total Risk-Based Capital to Risk-Weighted Assets  \
# 17005                                           11.7307
# 17006                                           11.3908
# 17007                                               NaN
# 17008                                           13.6232
# 17009                                           60.3380
#
#        Core Deposits as % of Total Assets  \
# 17005                               56.96
# 17006                               61.92
# 17007                               28.33
# 17008                               54.45
# 17009                               95.58
#
#        Short Term Assets as % of Short Term Liabilities  \
# 17005                                             66.61
# 17006                                             38.39
# 17007                                            144.47
# 17008                                             27.42
# 17009                                               NaN
#
#        Net Short Term Liabilities as % of Total Assets  \
# 17005                                             6.97
# 17006                                            16.49
# 17007                                            -7.76
# 17008                                            22.24
# 17009                                           -15.47
#
#        Net Loans Leases as % of Total Deposits  RIAD4230  RIADJJ33  \
# 17005                                    97.53       NaN    1304.0
# 17006                                    82.74       NaN   32049.0
# 17007                                    94.80       NaN   22005.0
# 17008                                    93.84       NaN   35305.0
# 17009                                     0.00       NaN       0.0
#
#          UBPR2170    UBPRD659
# 17005  12808007.0  13312497.0
# 17006  10718020.0  10406174.0
# 17007   8391265.0   8640596.0
# 17008  35784457.0  37499312.0
# 17009  11766000.0  12780500.0

# %%
bank_panel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17010 entries, 0 to 17009
# Data columns (total 18 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Report Date                                           17010 non-null  object
#  1   IDRSSD                                                17010 non-null  int64
#  2   Financial Institution Name                            17010 non-null  object
#  3   Provision for Loan Lease Losses as % of Aver. Assets  17010 non-null  float64
#  4   Provision_quarter as % of Assets                      16754 non-null  float64
#  5   Net Interest Income as % of Aver. Assets              17010 non-null  float64
#  6   Noninterest Income as % of Aver. Assets               17010 non-null  float64
#  7   Pre Provision Net Revenue as % of Aver. Assets        17010 non-null  float64
#  8   Tier One Leverage Capital                             17010 non-null  float64
#  9   Total Risk-Based Capital to Risk-Weighted Assets      16967 non-null  float64
#  10  Core Deposits as % of Total Assets                    17010 non-null  float64
#  11  Short Term Assets as % of Short Term Liabilities      16699 non-null  float64
#  12  Net Short Term Liabilities as % of Total Assets       17010 non-null  float64
#  13  Net Loans Leases as % of Total Deposits               16984 non-null  float64
#  14  RIAD4230                                              13646 non-null  float64
#  15  RIADJJ33                                              3364 non-null   float64
#  16  UBPR2170                                              17010 non-null  float64
#  17  UBPRD659                                              17010 non-null  float64
# dtypes: float64(15), int64(1), object(2)
# memory usage: 2.3+ MB

# %%
bank_panel_df.to_csv('df_response_vars.csv')

# %% [markdown]
# ##  Time series plots for potential response variables

# %% [markdown]
# ### The effect of economic crises on income and expenses

# %%
plot_response_var(bank_panel_df, 'Provision for Loan Lease Losses as % of Aver. Assets')

# %%
plot_response_var(bank_panel_df, 'Provision_quarter as % of Assets')

# %%
plot_response_var(bank_panel_df, 'Net Interest Income as % of Aver. Assets')

# %%
plot_response_var(bank_panel_df, 'Noninterest Income as % of Aver. Assets')

# %%
plot_response_var(bank_panel_df, 'Pre Provision Net Revenue as % of Aver. Assets')

# %% [markdown]
# ### The effect of economic crises on capital ratios

# %%
plot_response_var(bank_panel_df, 'Tier One Leverage Capital')

# %%
plot_response_var(bank_panel_df, 'Total Risk-Based Capital to Risk-Weighted Assets')

# %% [markdown]
# ### The effect of economic crises on liquidity

# %%
plot_response_var(bank_panel_df, 'Core Deposits as % of Total Assets')

# %%
plot_response_var(bank_panel_df, 'Short Term Assets as % of Short Term Liabilities', 0.1)

# %%
plot_response_var(bank_panel_df, 'Net Short Term Liabilities as % of Total Assets')

# %%
plot_response_var(bank_panel_df, 'Net Loans Leases as % of Total Deposits')

# %% [markdown]
# ## Provision for Loan Lease Losses as % of Aver. Assets

# %%
y_col = 'Provision for Loan Lease Losses as % of Aver. Assets'

# %%
bank_panel_df[y_col].describe()
# Out:
# count    17010.000000
# mean         0.528257
# std          1.354069
# min         -4.110000
# 25%          0.050000
# 50%          0.170000
# 75%          0.460000
# max         86.770000
# Name: Provision for Loan Lease Losses as % of Aver. Assets, dtype: float64

# %% [markdown]
# ### Outliers

# %%
# Check outliers on the test set
bank_panel_df = bank_panel_df[bank_panel_df['Report Date']<='2021-12-31']

# %%
# All points
plt.boxplot(bank_panel_df[y_col], vert=False)
plt.title('Provision for Loan Lease Losses as % of Aver. Assets Boxplot');

# %%
# Removing 2 outliers
plt.boxplot(bank_panel_df.loc[bank_panel_df[y_col]<20, y_col], vert=False)
plt.title('Provision for Loan Lease Losses as % of Aver. Assets Boxplot');

# %%
# Removing outliers from both sides
lower_limit = np.percentile(bank_panel_df[y_col], 0.5)
upper_limit = np.percentile(bank_panel_df[y_col], 99)
plt.boxplot(bank_panel_df.loc[(bank_panel_df[y_col]>lower_limit)&\
                              (bank_panel_df[y_col]<upper_limit), y_col], 
            vert=False)
plt.title('Provision for Loan Lease Losses as % of Aver. Assets Boxplot');

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 2))

ax1.boxplot(bank_panel_df[y_col], vert=False)
ax2.boxplot(bank_panel_df.loc[(bank_panel_df[y_col]>lower_limit)&\
                              (bank_panel_df[y_col]<upper_limit), y_col], 
            vert=False)

ax1.set_title('All data points within the training time period')
ax2.set_title('After removing outliers (the bottom 0.5% and top 1%)')

fig.suptitle('Distribution of response variable values', fontsize=14, y=1.17);
